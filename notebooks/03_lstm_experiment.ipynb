# %% [markdown]
# # 03 — Optional LSTM time-series experiment
#
# The AI4I CSV is mostly **tabular** (one row per machine snapshot). For production tractors you would log **sequences** (windows of RPM/temp/torque) and train an LSTM/GRU or Temporal Convolutional network.
#
# Sketch:
# 1. Build sliding windows of length `W` over each asset’s timeline.
# 2. Scale per feature; label window with failure within next `H` steps.
# 3. `tensorflow.keras` — `LSTM(64)` → `Dense` → `softmax` over failure types.
#
# Install: `pip install tensorflow` then implement below when you have sequential logs.

# %%
# Placeholder — uncomment when tensorflow is installed and you have sequential data.
# import numpy as np
# import tensorflow as tf
# from tensorflow.keras import Sequential
# from tensorflow.keras.layers import LSTM, Dense
# print(tf.__version__)
